# %% [markdown]
# # Q1

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.gca()
ax.set_xticks(np.arange(-5, 5, 1))
ax.set_yticks(np.arange(-5, 5, 1))
plt.grid()
plt.show()

# %% [markdown]
# # Q2

# %%
X = [0,0]
Y = [0,0]
U = [1,-1] 
V = [2,2] 
fig, ax = plt.subplots()
ax.quiver(X, Y, U, V,color=['g','r'], angles='xy', scale_units='xy',scale=1)
ax.set_xticks(np.arange(-5, 5, 1))
ax.set_yticks(np.arange(-5, 5, 1))
plt.grid()
plt.show()

# %% [markdown]
# # Q3

# %%
scaler = np.arange(-10, 10, 0.01)
scaler = scaler.reshape(scaler.shape[0], 1)
np.random.shuffle(scaler)

scaler2 = np.arange(-10, 10, 0.01)
scaler2 = scaler2.reshape(scaler2.shape[0], 1)
np.random.shuffle(scaler2)

fig, ax = plt.subplots()

i = 0

for x in scaler:
    U = [x - scaler2[i], scaler2[i] - x]
    V = [x*2 + scaler2[i]*2, x*2 + scaler2[i]*2]
    i += 1
    plt.plot(U, V,'b.')
        
plt.xlim(-5,5)
plt.ylim(-5,5)

plt.grid()
plt.show()

# %% [markdown]
# ###### با کوچکتر کردن مقدار آرگومان سوم این تابع اعداد بیشتری هستند که ترکیب خطی را ایجاد کنند و اسپن نقاط بیشتری را در کل صفحه در بر می گیرد
